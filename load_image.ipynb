# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

matplotlib.rcParams['figure.dpi'] = 150
figsize = plt.rcParams.get('figure.figsize')
plt.rcParams['figure.figsize'] = [x * 2 for x in figsize]

# %%
import cv2

# %%
img = cv2.imread('images/pic1.jpg')
# Out:
# [ WARN:0@10869.820] global loadsave.cpp:244 findDecoder imread_('images/pic1.jpg'): can't open/read file: check file path/integrity

# %%
# !ls
# Out:
# collection.jpg	pic1.jpg  pic3.jpg  pic5.jpg  Untitled.ipynb
# living.jpg	pic2.jpg  pic4.jpg  thumb

# %%
img.shape
# Out:
# (1280, 1706, 3)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %%
plt.imshow(img[:, :, 1], cmap='gray')
#plt.imshow(red_channel, cmap='gray')

# %%
img[:, :, 0]
# Out:
# array([[151, 151, 151, ..., 198, 198, 198],
#        [153, 153, 153, ..., 198, 198, 198],
#        [156, 156, 156, ..., 198, 198, 198],
#        ...,
#        [116, 116, 116, ..., 158, 156, 156],
#        [115, 116, 117, ..., 156, 157, 157],
#        [115, 116, 117, ..., 154, 158, 158]], dtype=uint8)

# %%
img[0, 0]
# Out:
# array([151, 167, 167], dtype=uint8)

# %%
# Out:
# 153

# %%
# CV2.    Blue green and red
# plotting:   Red green Blue
